# %% [markdown]
# <a href="https://colab.research.google.com/github/MarquezIMatias/challenge-alura-store/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
import pandas as pd
import matplotlib.pyplot as plt


url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
tienda2.head()
# Out:
#            Producto  Categoría del Producto    Precio  Costo de envío  \
# 0  Silla de oficina                 Muebles  283600.0         15300.0
# 1         Pandereta  Instrumentos musicales   76800.0          2300.0
# 2         Cama king                 Muebles  443300.0         23800.0
# 3         Cama king                 Muebles  906200.0         46400.0
# 4  Silla de oficina                 Muebles  397800.0         19400.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      04/08/2021  Izabela de León        Medellín             1
# 1      26/11/2020   Blanca Ramirez        Medellín             3
# 2      22/10/2021  Izabela de León         Pereira             5
# 3      04/05/2022    Maria Alfonso            Cali             5
# 4      26/02/2022    Lucas Olivera          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0               Nequi                   1  6.25184 -75.56359
# ...

# %%
tienda3.head()
# Out:
#             Producto  Categoría del Producto     Precio  Costo de envío  \
# 0   Secadora de ropa       Electrodomésticos  1285100.0         66600.0
# 1      Mesa de noche                 Muebles   290100.0         13600.0
# 2  Guitarra acústica  Instrumentos musicales   303500.0         17400.0
# 3  Balón de voleibol    Deportes y diversión    58800.0          3300.0
# 4            Armario                 Muebles   521100.0         25900.0
#
#   Fecha de Compra        Vendedor Lugar de Compra  Calificación  \
# 0      17/12/2021   Camila Rivera     Santa Marta             4
# 1      10/02/2021   Maria Alfonso            Cali             3
# 2      22/01/2023   Lucas Olivera          Bogotá             5
# 3      22/03/2022     Pedro Gomez    Barranquilla             4
# 4      12/01/2022  Blanca Ramirez          Bogotá             1
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   4  11.24079 -74.19904
# ...

# %%
tienda4.head()
# Out:
#               Producto Categoría del Producto     Precio  Costo de envío  \
# 0         Lavavajillas      Electrodomésticos  1084800.0         56000.0
# 1             Cama box                Muebles   473800.0         25400.0
# 2  Balón de baloncesto   Deportes y diversión    23700.0             0.0
# 3  Modelado predictivo                 Libros    57700.0          1300.0
# 4          Auriculares           Electrónicos   138900.0          5600.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      11/11/2022    Rafael Acosta          Bogotá             4
# 1      03/01/2020  Izabela de León          Cúcuta             5
# 2      25/12/2022    Maria Alfonso        Medellín             5
# 3      23/11/2021    Lucas Olivera        Medellín             3
# 4      25/04/2022   Blanca Ramirez          Bogotá             4
#
#        Método de pago  Cantidad de cuotas      lat       lon
# 0  Tarjeta de crédito                   3  4.60971 -74.08175
# ...

# %% [markdown]
# #1. **Análisis de facturación**

# %% [markdown]
# ## a. Tienda

# %%
suma_total_precio = tienda['Precio'].sum()
print(f'El Ingreso Total de la Tienda es: ${suma_total_precio}')
# Out:
# El Ingreso Total de la Tienda es: $1150880400.0

# %% [markdown]
# ## b. Tienda2

# %%
suma_total_precio2 = tienda2['Precio'].sum()
print(f'El Ingreso Total de la Tienda 2 es: ${suma_total_precio2}')
# Out:
# El Ingreso Total de la Tienda 2 es: $1116343500.0

# %% [markdown]
# ## c. Tienda3

# %%
suma_total_precio3 = tienda3['Precio'].sum()
print(f'El Ingreso Total de la Tienda 3 es: ${suma_total_precio3}')
# Out:
# El Ingreso Total de la Tienda 3 es: $1098019600.0

# %% [markdown]
# ## d. Tienda4

# %%
suma_total_precio4 = tienda4['Precio'].sum()
print(f'El Ingreso Total de la Tienda 4 es: ${suma_total_precio4}')
# Out:
# El Ingreso Total de la Tienda 4 es: $1038375700.0

# %% [markdown]
# ## **Conclusión**

# %%
mayor_ingreso = max(suma_total_precio, suma_total_precio2, suma_total_precio3, suma_total_precio4)
print(f'El mayor ingreso fue de: ${mayor_ingreso}')
# Out:
# El mayor ingreso fue de: $1150880400.0

# %% [markdown]
# El Ranking de los ingresos de facturacíon, quedo conformado de la siguiente manera:
#
# 1. La tienda con $1.150.880.400.0
#
# 2. La tienda2 con $1.116.343.500.0
#
# 3. La tienda3 con $1.098.019.600.0
#
# 4. La tienda4 con $1.038.375.700.0

# %% [markdown]
# # 2. **Ventas por categoría**

# %% [markdown]
# ## a. Tienda

# %%
tienda['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64

# %%
cat_tienda = tienda['Categoría del Producto'].value_counts()
cat_tienda.plot(kind='barh', figsize=(10,6), color='gold')
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# ## b. Tienda2

# %%
tienda2['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64

# %%
cat_tienda2 = tienda2['Categoría del Producto'].value_counts()
cat_tienda2.plot(kind='barh', figsize=(10,6), color='blue')
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# ## c. Tienda3

# %%
tienda3['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64

# %%
cat_tienda3 = tienda3['Categoría del Producto'].value_counts()
cat_tienda3.plot(kind='barh', figsize=(10,6), color='green')
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# ## d. Tienda4

# %%
tienda4['Categoría del Producto'].value_counts()
# Out:
# Categoría del Producto
# Muebles                    480
# Electrónicos               451
# Juguetes                   338
# Deportes y diversión       277
# Electrodomésticos          254
# Artículos para el hogar    201
# Libros                     187
# Instrumentos musicales     170
# Name: count, dtype: int64

# %%
cat_tienda4 = tienda4['Categoría del Producto'].value_counts()
cat_tienda4.plot(kind='barh', figsize=(10,6), color='red')
# Out:
# <Axes: ylabel='Categoría del Producto'>

# %% [markdown]
# ## **Conclusión**
#
# Observando el número total de ventas por "Categoría del Producto" de todas las tiendas, se determino que:
#
# 1 - Los Muebles, Electrónicos y Juguetes son las Categoriás mas populares.
#
# 2 - Los Articulos para el Hogar, Libros e Instrumentos Musicales son los menos populares.

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# ## a. Tienda

# %%
tienda['Calificación'].mean()
calificacion_tienda = tienda['Calificación'].mean().round(2)
print(f'La calificación promedio de la tienda es: {calificacion_tienda}')
# Out:
# La calificación promedio de la tienda es: 3.98

# %% [markdown]
# ## b. Tienda2

# %%
tienda2['Calificación'].mean()
calificacion_tienda2 = tienda2['Calificación'].mean().round(2)
print(f'La calificación promedio de la tienda2 es: {calificacion_tienda2}')
# Out:
# La calificación promedio de la tienda2 es: 4.04

# %% [markdown]
# ## c. Tienda3

# %%
tienda3['Calificación'].mean()
calificacion_tienda3 = tienda3['Calificación'].mean().round(2)
print(f'La calificación promedio de la tienda3 es: {calificacion_tienda3}')
# Out:
# La calificación promedio de la tienda3 es: 4.05

# %% [markdown]
# ## d. Tienda4

# %%
tienda4['Calificación'].mean()
calificacion_tienda4 = tienda4['Calificación'].mean().round(2)
print(f'La calificación promedio de la tienda3 es: {calificacion_tienda4}')
# Out:
# La calificación promedio de la tienda3 es: 4.0

# %% [markdown]
# ## **Conclusión**

# %%
mayor_calificacion = max(calificacion_tienda, calificacion_tienda2, calificacion_tienda3, calificacion_tienda4)
print(f'La mayor calificación fue de: {mayor_calificacion}')
# Out:
# La mayor calificación fue de: 4.05

# %% [markdown]
# La Tienda que tiene mayor satisfacción del cliente con los productos vendidos es la "tienda3"

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# ## a. Tienda

# %%
producto_mas_vendido_tienda = tienda['Producto'].value_counts().head(5).sort_values(ascending=False)
producto_mas_vendido_tienda.plot(kind='barh', figsize=(10,4), color='gold')
producto_mas_vendido_tienda
# Out:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64

# %%
producto_menos_vendido_tienda = tienda['Producto'].value_counts().tail(5).sort_values(ascending=True)
producto_menos_vendido_tienda.plot(kind='barh', figsize=(10,4), color='gold')
producto_menos_vendido_tienda
# Out:
# Producto
# Auriculares con micrófono      33
# Celular ABXY                   33
# Olla de presión                35
# Pandereta                      36
# Ciencia de datos con Python    39
# Name: count, dtype: int64

# %% [markdown]
# ## b. Tienda2

# %%
producto_mas_vendido_tienda2 = tienda2['Producto'].value_counts().head(5).sort_values(ascending=False)
producto_mas_vendido_tienda2.plot(kind='barh', figsize=(10,4), color='blue')
producto_mas_vendido_tienda2
# Out:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64

# %%
producto_menos_vendido_tienda2 = tienda2['Producto'].value_counts().tail(5).sort_values(ascending=True)
producto_menos_vendido_tienda2.plot(kind='barh', figsize=(10,4), color='blue')
producto_menos_vendido_tienda2
# Out:
# Producto
# Juego de mesa      32
# Impresora          34
# Mesa de comedor    34
# Sillón             35
# Auriculares        37
# Name: count, dtype: int64

# %% [markdown]
# ## c. Tienda3

# %%
producto_mas_vendido_tienda3 = tienda3['Producto'].value_counts().head(5).sort_values(ascending=False)
producto_mas_vendido_tienda3.plot(kind='barh', figsize=(10,4), color='green')
producto_mas_vendido_tienda3
# Out:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64

# %%
producto_menos_vendido_tienda3 = tienda3['Producto'].value_counts().tail(5).sort_values(ascending=True)
producto_menos_vendido_tienda3.plot(kind='barh', figsize=(10,4), color='green')
producto_menos_vendido_tienda3
# Out:
# Producto
# Bloques de construcción    35
# Set de vasos               36
# Microondas                 36
# Mochila                    36
# Guitarra eléctrica         38
# Name: count, dtype: int64

# %% [markdown]
# ## d. Tienda4

# %%
producto_mas_vendido_tienda4 = tienda4['Producto'].value_counts().head(5).sort_values(ascending=False)
producto_mas_vendido_tienda4.plot(kind='barh', figsize=(10,4), color='red')
producto_mas_vendido_tienda4
# Out:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64

# %%
producto_menos_vendido_tienda4 = tienda4['Producto'].value_counts().tail(5).sort_values(ascending=True)
producto_menos_vendido_tienda4.plot(kind='barh', figsize=(10,4), color='red')
producto_menos_vendido_tienda4
# Out:
# Producto
# Guitarra eléctrica             33
# Armario                        34
# Guitarra acústica              37
# Ciencia de datos con Python    38
# Refrigerador                   38
# Name: count, dtype: int64

# %% [markdown]
# ## **Conclusión**

# %% [markdown]
# 1.   Tienda
#
#     *   Productos mayor vendidos: Microondas(60), TV LED UHD 4(60) y Armarios(60)
#     *   Productos menor vendidos: Auriculares con micrófono(33) y Celular ABXY(33)
#
#
# 2.   Tienda2
#
#     *   Productos mayor vendidos: Libro:Iniciando en programación(65), Microondas(62) y Baterías (61)
#     *   Productos menor vendidos: Juego de mesa(32), Impresora(34) y Mesa de comedor(34)
#
# 3.   Tienda3
#
#     *   Productos mayor vendidos: Kit de bancas(57), Mesa de comedor(56) y Cama king(56)
#     *   Productos menor vendidos: Bloques de construcción(35), Set de vasos(36) y Microondas(36)
#
# 4.   Tienda4
#
#
#     *   Productos mayor vendidos: Cama box(62), Cubertería(59) y Dashboards con Power BI(56)
#     *   Productos menor vendidos: Guitarra eléctrica(33), Armario(34) y Guitarra acústica(37)

# %% [markdown]
# # 5. Envío promedio por tienda

# %% [markdown]
# ## a. Tienda

# %%
promedio_envio_tienda = tienda['Costo de envío'].mean().round(2)
print(f'El promedio de costo de envío de la tienda es: ${promedio_envio_tienda}')
# Out:
# El promedio de costo de envío de la tienda es: $26018.61

# %%
suma_total_promedio_tienda = tienda['Costo de envío'].sum().round(2)
print(f'El Costo Total de Envío de la Tienda es: ${suma_total_promedio_tienda}')
# Out:
# El Costo Total de Envío de la Tienda es: $61377900.0

# %% [markdown]
# ## b. Tienda2

# %%
promedio_envio_tienda2 = tienda2['Costo de envío'].mean().round(2)
print(f'El promedio de costo de envío de la tienda2 es: ${promedio_envio_tienda2}')
# Out:
# El promedio de costo de envío de la tienda2 es: $25216.24

# %%
suma_total_promedio_tienda2 = tienda2['Costo de envío'].sum().round(2)
print(f'El Costo Total de Envío de la Tienda2 es: ${suma_total_promedio_tienda2}')
# Out:
# El Costo Total de Envío de la Tienda2 es: $59485100.0

# %% [markdown]
# ## c. Tienda3

# %%
promedio_envio_tienda3 = tienda3['Costo de envío'].mean().round(2)
print(f'El promedio de costo de envío de la tienda es: ${promedio_envio_tienda3}')
# Out:
# El promedio de costo de envío de la tienda es: $24805.68

# %%
suma_total_promedio_tienda3 = tienda3['Costo de envío'].sum().round(2)
print(f'El Costo Total de Envío de la Tienda es: ${suma_total_promedio_tienda3}')
# Out:
# El Costo Total de Envío de la Tienda es: $58516600.0

# %% [markdown]
# ## d. Tienda4

# %%
promedio_envio_tienda4 = tienda4['Costo de envío'].mean().round(2)
print(f'El promedio de costo de envío de la tienda es: ${promedio_envio_tienda4}')
# Out:
# El promedio de costo de envío de la tienda es: $23459.46

# %%
suma_total_promedio_tienda4 = tienda4['Costo de envío'].sum().round(2)
print(f'El Costo Total de Envío de la Tienda es: ${suma_total_promedio_tienda4}')
# Out:
# El Costo Total de Envío de la Tienda es: $55317400.0

# %% [markdown]
# ### **Conclusión**

# %%
mayor_promedio_tiendas = max(promedio_envio_tienda, promedio_envio_tienda2, promedio_envio_tienda3, promedio_envio_tienda4)
print(f'El mayor promedio de envío fue de: ${mayor_promedio_tiendas}')
# Out:
# El mayor promedio de envío fue de: $26018.61

# %% [markdown]
# El Ranking de los Costos Promedios de Envió, quedo conformado de la siguiente manera:
#
# 1. La tienda con $26018.61
#
# 2. La tienda2 con $25216.24
#
# 3. La tienda3 con $24805.68
#
# 4. La tienda4 con $23459.46

# %% [markdown]
# # **INFORME FINAL**

# %% [markdown]
# ### **. Ingresos totales de las tiendas.**

# %%
plt.bar(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [suma_total_precio, suma_total_precio2, suma_total_precio3, suma_total_precio4],color="green")
for x, y in zip(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [suma_total_precio, suma_total_precio2, suma_total_precio3, suma_total_precio4]):
    plt.text(x, y, str(y), ha='center', va='bottom')

plt.xlabel('Tiendas')
plt.ylabel('Ingresos')
plt.title('Ingresos por Tienda')
plt.show()

# %% [markdown]
# ### **. Categorías de productos más y menos vendidas.**

# %%
total_categorias = (cat_tienda.add(cat_tienda2, fill_value=0).add(cat_tienda3, fill_value=0).add(cat_tienda4, fill_value=0))

total_categorias = total_categorias.sort_values(ascending=False)

plt.figure(figsize=(14, 10))
plt.pie(
    total_categorias.values,
    labels=total_categorias.index,
    autopct="%1.1f%%",
    startangle=90
)

plt.title("Distribución total de ventas por categoría (Tiendas 1, 2, 3 y 4)")
plt.axis("equal")
plt.show()

# %% [markdown]
# ### **. Calificaciones promedio de los clientes por tienda.**

# %%
plt.bar(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [calificacion_tienda, calificacion_tienda2, calificacion_tienda3, calificacion_tienda4],color="blue")
for x, y in zip(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [calificacion_tienda, calificacion_tienda2, calificacion_tienda3, calificacion_tienda4]):
    plt.text(x, y, str(y), ha='center', va='bottom')

plt.xlabel('Tiendas')
plt.ylabel('Calificación')
plt.title('Calificación Promedio por Tienda')
plt.show()

# %% [markdown]
# ### **. Productos más y menos vendidos.**

# %%
ranked1 = producto_mas_vendido_tienda.head(5)
ranked2 = producto_mas_vendido_tienda2.head(5)
ranked3 = producto_mas_vendido_tienda3.head(5)
ranked4 = producto_mas_vendido_tienda4.head(5)

ranked_todas = (ranked1.add(ranked2, fill_value=0).add(ranked3, fill_value=0).add(ranked4, fill_value=0))

ranked_todas = ranked_todas.sort_values(ascending=False)

plt.figure(figsize=(10, 10))
plt.pie(ranked_todas.values, labels=ranked_todas.index, autopct="%1.1f%%", startangle=90)

plt.title("Top 5 productos más vendidos (combinado de todas las tiendas)")
plt.axis("equal")
plt.show()

# %%
low1 = producto_menos_vendido_tienda.tail(5)
low2 = producto_menos_vendido_tienda2.tail(5)
low3 = producto_menos_vendido_tienda3.tail(5)
low4 = producto_menos_vendido_tienda4.tail(5)


low_todas = (low1.add(low2, fill_value=0).add(low3, fill_value=0).add(low4, fill_value=0))

low_todas = low_todas.sort_values(ascending=False)

plt.figure(figsize=(10, 10))
plt.pie(low_todas.values, labels=low_todas.index, autopct="%1.1f%%", startangle=90)

plt.title("Top 5 productos menos vendidos (combinado de todas las tiendas)")
plt.axis("equal")
plt.show()

# %% [markdown]
# ### **. Coste de envío promedio para cada tienda**

# %%
plt.bar(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [promedio_envio_tienda, promedio_envio_tienda2, promedio_envio_tienda3, promedio_envio_tienda4],color="gold")
for x, y in zip(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [promedio_envio_tienda, promedio_envio_tienda2, promedio_envio_tienda3, promedio_envio_tienda4]):
    plt.text(x, y, str(y), ha='center', va='bottom')

plt.xlabel('Tiendas')
plt.ylabel('Costo')
plt.title('Costo de Envío Promedio por Tienda')
plt.show()

# %%
plt.bar(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [suma_total_promedio_tienda, suma_total_promedio_tienda2, suma_total_promedio_tienda3, suma_total_promedio_tienda4],color="purple")
for x, y in zip(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [suma_total_promedio_tienda, suma_total_promedio_tienda2, suma_total_promedio_tienda3, suma_total_promedio_tienda4]):
    plt.text(x, y, str(y), ha='center', va='bottom')

plt.xlabel('Tiendas')
plt.ylabel('Costo')
plt.title('Costo de Envío Promedio por Tienda')
plt.show()

# %% [markdown]
# # **JUSTIFICACION**

# %% [markdown]
# Considerando todos los análisis a la vista, se recomienda al Sr. Juan que haga efectiva la venta de la **Tienda 4**. Se determina esta situación de acuerdo a las siguientes conclusiones:
#
#
# 1.   **FACTURACION** - Esta tienda es la que **menos** ingresos totales posee.
#
# 2.   **CALIFICACION** - Si bien no tiene la peor calificacíon por parte de los clientes, sólo lo supera por 2 centésimos la **Tienda 1**.
#
#
# Así tambien se considera:
#
# *   Invertir a largo plazo en la **Tienda 2**, debido a su estabilidad, buen desempeño y rentabilidad constante.
# *   Analizar los factores de éxito en ingresos de la **Tienda 1**, evaluar la viabilidad de replicarlos en las demás sucursales para mejorar el rendimiento en cada Tienda y revertir el nivel bajo de la calificación por parte de los clientes.
#
# *   Promocionar los productos más vendidos para atraer mayor cantidad de clientes y aumentar los ingresos, manteniendo siempre un excelente servicio al cliente en todas las tiendas.
